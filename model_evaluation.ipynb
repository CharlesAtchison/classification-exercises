# %% [markdown]
# ## <center>2.</center>
#
# Given the following confusion matrix, evaluate (by hand) the model's performance.
#
#
# |               | pred dog   | pred cat   |
# |:------------  |-----------:|-----------:|
# | actual dog    |         46 |         7  |
# | actual cat    |         13 |         34 |
#
# * In the context of this problem, what is a false positive?
#
#     * __predicted a dog, but actually a cat and vice-versa__
#
#
# * In the context of this problem, what is a false negative?
#
#     * __predicted it wasn't a cat but actually a dog, and vice-versa__
#
#
# * How would you describe this model?
#
#     *  **dog/cat prediction model**

# %% [markdown]
# ## <center>3.</center>
#
# You are working as a datascientist working for Codeup Cody Creator (C3 for short), a rubber-duck manufacturing plant.
#
# Unfortunately, some of the rubber ducks that are produced will have defects. Your team has built several models that try to predict those defects, and the data from their predictions can be found here.
#
# Use the predictions dataset and pandas to help answer the following questions:
#
#
#
# <table>
#     <tr><th><center>Model 1</center></th><th><center>Model 2</center></th><th><center>Model 3</center></th></tr>
# <tr><td>
#
# | Actual Defect   |   Defect |   No Defect |
# |:----------------|---------:|------------:|
# | Defect          |        8 |           8 |
# | No Defect       |        2 |         182 |
# | Precison %       |       80.00 |          --- |
# | Recall %       |       50.00 |          --- |
#
# </td><td>
#
# |Actual Defect |   Defect |   No Defect |
# |:----------------|---------:|------------:|
# | Defect          |        9 |           7 |
# | No Defect       |       81 |         103 |
# | Precision %       |       10.00 |          --- |
# | Recall %       |       56.25 |          --- |
#
# </td><td>
#
# |  Actual Defect  |   Defect |   No Defect |
# |:----------------|---------:|------------:|
# | Defect          |     13 |           3 |
# | No Defect       |     86 |          98 |
# | Precision %     |  13.13 |          --- |
# | Recall %        |  81.25 |          --- |
#
# </td></tr></table>
#
#
# * An internal team wants to investigate the cause of the manufacturing defects. They tell you that they want to identify as many of the ducks that have a defect as possible. Which evaluation metric would be appropriate here? Which model would be the best fit for this use case?
#
#     * __You would want to minimize false negatives (where you missed detecting a defect), which would be the recall method. Using model3 would be best for a recall method.__
#
#
# * Recently several stories in the local news have come out highlighting customers who received a rubber duck with a defect, and portraying C3 in a bad light. The PR team has decided to launch a program that gives customers with a defective duck a vacation to Hawaii. They need you to predict which ducks will have defects, but tell you the really don't want to accidentally give out a vacation package when the duck really doesn't have a defect. Which evaluation metric would be appropriate here? Which model would be the best fit for this use case?
#
#     * __You would want to minimize false positives (where you missed detecting a no defect), which would be the precision method. Using model1 would be best for a precision method.__

# %%
import pandas as pd
import numpy as np

c3 = pd.read_csv('c3.csv')

## Recall you want to minimum amount of false negatives

val = pd.crosstab(c3.actual, c3.model1, rownames=['Actual Defect'], colnames=['Pred Defect'])



# recalls 

# subset = c3[c3.actual == 'Defect']


# m1 = (subset.actual == subset.model1).mean()
# m2 = (subset.actual == subset.model2).mean()
# m3 = (subset.actual == subset.model3).mean()
# m1, m2, m3


# precision 

# sub1 = c3[c3.model1 == 'Defect']
# sub2 = c3[c3.model2 == 'Defect']
# sub3 = c3[c3.model3 == 'Defect']

# m1 = (sub1.actual == sub1.model1).mean()
# m2 = (sub2.actual == sub2.model2).mean()
# m3 = (sub3.actual == sub3.model3).mean()

# m1, m2, m3

# %% [markdown]
# ## <center>4.</center>
#
# You are working as a data scientist for Gives You Paws ™, a subscription based service that shows you cute pictures of dogs or cats (or both for an additional fee).
#
# At Gives You Paws, anyone can upload pictures of their cats or dogs. The photos are then put through a two step process. First an automated algorithm tags pictures as either a cat or a dog (Phase I). Next, the photos that have been initially identified are put through another round of review, possibly with some human oversight, before being presented to the users (Phase II).
#
# Several models have already been developed with the data, and you can find their results here.
#
# Given this dataset, use pandas to create a baseline model (i.e. a model that just predicts the most common class) and answer the following questions:
#
#
#
# <center><h1>Dog</h1></center>
#     <table>
#     <tr><th><center>Model1</center></th><th><center>Model2</center></th><th><center>Model3</center></th><th><center>Model4</center></th></tr>
#     <tr><td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |  1423 |   640 |
# | dog    |   323 |  2614 |
# | Precision|---|89.00%|
# | Recall|---|80.33%|
#
# </td>
#
# <td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |  1555 |  1657 |
# | dog    |   191 |  1597 |
# | Precision|---|89.32%|
# | Recall|---|49.08%|
#
# </td>
#
# <td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |   893 |  1599 |
# | dog    |   853 |  1655 |
# | Precision|---|65.99%|
# | Recall|---|50.86%|
#
# </td>
#
# <td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |   603 |   144 |
# | dog    |  1143 |  3110 |
# | Precision|---|73.12%|
# | Recall|---|95.57%|
#
# </td>
#
# </tr> </table>
# <center><h1>Cat</h1></center>
#     <table>
#     <tr><th><center>Model1</center></th><th><center>Model2</center></th><th><center>Model3</center></th><th><center>Model4</center></th></tr>
#     <tr><td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |  1423 |   640 |
# | dog    |   323 |  2614 |
# | Precision|---|68.98%|
# | Recall|---|81.50%|
#
# </td>
#
# <td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |  1555 |  1657 |
# | dog    |   191 |  1597 |
# | Precision|---|48.41%|
# | Recall|---|89.06%|
#
# </td>
#
# <td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |   893 |  1599 |
# | dog    |   853 |  1655 |
# | Precision|---|35.83%|
# | Recall|---|51.15%|
#
# </td>
#
# <td>
#
# | Pred   |   cat |   dog |
# |:-------|------:|------:|
# | cat    |   603 |   144 |
# | dog    |  1143 |  3110 |
# | Precision|---|80.72%|
# | Recall|---|34.54%|
#
# </td>
#
# </tr> </table>
#
#
#
#
# In terms of accuracy, how do the various models compare to the baseline model? Are any of the models better than the baseline?
#
# * Baseline percentange is 65.08
# * Only model4 performs better than the baseline with 85.06% accuracy.
#
#
# Suppose you are working on a team that solely deals with dog pictures. Which of these models would you recomend for Phase I? For Phase II?
#
# * Phase I:
#     * It would be model
#
# * Phase II:
#
# Suppose you are working on a team that solely deals with cat pictures. Which of these models would you recomend for Phase I? For Phase II?
#
# * Phase I
#
# * Phase II:
#
#
# '|    |    0 |    1 |\n|---:|-----:|-----:|\n|  0 | 1423 |  323 |\n|  1 |  640 | 2614 |'

# %%
from data_evaluation import confusion_table

data = pd.read_csv('gives_you_paws.csv')

    
    
# confusion_table(data, 'dog')
print(confusion_table(data, 'dog'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee6ae61d3c26> in <module>
#       6
#       7 # confusion_table(data, 'dog')
# ----> 8 print(confusion_table(data, 'dog'))
#
# ~/codeup-data-science/classification-exercises/data_evaluation.py in confusion_table(df, target)
#      32     for col in col_names:
#      33         val = pd.crosstab(df[col], df.actual, rownames=['Pred'], colnames=['Actual']).to_markdown()
# ---> 34         recall_subset = data[data.actual == target]
#      35         recall_val = (recall_subset.actual == recall_subset[col]).mean() * 100
#      36         precision_subset = df[df[col] == target]
#
# NameError: name 'data' is not defined

# %%
data = pd.read_csv('gives_you_paws.csv')
from sklearn.metrics import confusion_matrix
# Dog is the most common class as there are 3254 dogs
# and 1746 cats in actual column

# Accuracy
data['baseline'] = 'dog'

(data.baseline == data.model4).mean()

print(pd.DataFrame(confusion_matrix(data.actual, data.model1)).to_markdown())

# %% [markdown]
# ## <center>5.</center>
#
# Follow the links below to read the documentation about each function, then apply those functions to the data from the previous problem.
#
# sklearn.metrics.accuracy_score
# sklearn.metrics.precision_score
# sklearn.metrics.recall_score
# sklearn.metrics.classification_report
